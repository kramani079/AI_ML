# %% [markdown]
# K-means Clusttering without the elbow method

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
#Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#selecting only the first two features for visualization
x = df[['sepal length (cm)', 'sepal width (cm)']].values

# %%
#standardize the data
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# 1. select k (no of clusters)

# %% [markdown]
# 2. initialize centroids

# %% [markdown]
# 3. assign data points to nearest centroid

# %% [markdown]
# 4. update centroid

# %% [markdown]
# 5. repeat step 3 and 4 till centroids doesn't change
